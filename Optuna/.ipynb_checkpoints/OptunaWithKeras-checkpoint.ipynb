# %% [markdown]
# # Keras에도 적용 가능함

# %%
"""
Optuna example that optimizes a neural network classifier configuration for the
MNIST dataset using Keras.
In this example, we optimize the validation accuracy of MNIST classification using
Keras. We optimize the filter and kernel size, kernel stride and layer activation.
"""
import urllib
import warnings

import optuna

from keras.backend import clear_session
from keras.datasets import mnist
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop


# TODO(crcrpar): Remove the below three lines once everything is ok.
# Register a global custom opener to avoid HTTP Error 403: Forbidden when downloading MNIST.
opener = urllib.request.build_opener()
opener.addheaders = [("User-agent", "Mozilla/5.0")]
urllib.request.install_opener(opener)


N_TRAIN_EXAMPLES = 3000
N_VALID_EXAMPLES = 1000
BATCHSIZE = 128
CLASSES = 10
EPOCHS = 10


def objective(trial):
    # Clear clutter from previous Keras session graphs.
    clear_session()

    (x_train, y_train), (x_valid, y_valid) = mnist.load_data()
    img_x, img_y = x_train.shape[1], x_train.shape[2]
    x_train = x_train.reshape(-1, img_x, img_y, 1)[:N_TRAIN_EXAMPLES].astype("float32") / 255
    x_valid = x_valid.reshape(-1, img_x, img_y, 1)[:N_VALID_EXAMPLES].astype("float32") / 255
    y_train = y_train[:N_TRAIN_EXAMPLES]
    y_valid = y_valid[:N_VALID_EXAMPLES]
    input_shape = (img_x, img_y, 1)

    model = Sequential()
    model.add(
        Conv2D(
            filters=trial.suggest_categorical("filters", [32, 64]),
            kernel_size=trial.suggest_categorical("kernel_size", [3, 5]),
            strides=trial.suggest_categorical("strides", [1, 2]),
            activation=trial.suggest_categorical("activation", ["relu", "linear"]),
            input_shape=input_shape,
        )
    )
    model.add(Flatten())
    model.add(Dense(CLASSES, activation="softmax"))

    # We compile our model with a sampled learning rate.
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1e-1, log=True)
    model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=RMSprop(learning_rate=learning_rate),
        metrics=["accuracy"],
    )

    model.fit(
        x_train,
        y_train,
        validation_data=(x_valid, y_valid),
        shuffle=True,
        batch_size=BATCHSIZE,
        epochs=EPOCHS,
        verbose=False,
    )

    # Evaluate the model accuracy on the validation set.
    score = model.evaluate(x_valid, y_valid, verbose=0)
    return score[1]


if __name__ == "__main__":
    warnings.warn(
        "Recent Keras release (2.4.0) simply redirects all APIs "
        "in the standalone keras package to point to tf.keras. "
        "There is now only one Keras: tf.keras. "
        "There may be some breaking changes for some workflows by upgrading to keras 2.4.0. "
        "Test before upgrading. "
        "REF:https://github.com/keras-team/keras/releases/tag/2.4.0"
    )
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=100, timeout=600)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
# Out:
. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:21:26,512] Trial 40 finished with value: 0.9390000104904175 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.002346091968116026}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:21:32,496] Trial 41 finished with value: 0.9319999814033508 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.0060220273290121674}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:21:45,259] Trial 42 finished with value: 0.9409999847412109 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.0037662000589689004}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:21:53,187] Trial 43 finished with value: 0.9419999718666077 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.021530221153746993}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:21:59,523] Trial 44 finished with value: 0.9070000052452087 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.0010367049116925297}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:22:05,793] Trial 45 finished with value: 0.9319999814033508 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.05453876426308919}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:22:11,939] Trial 46 finished with value: 0.8309999704360962 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'linear', 'learning_rate': 0.010480824851057492}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:22:28,579] Trial 47 finished with value: 0.9359999895095825 and parameters: {'filters': 64, 'kernel_size': 3, 'strides': 1, 'activation': 'relu', 'learning_rate': 0.005153244262890333}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:22:35,074] Trial 48 finished with value: 0.9340000152587891 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.0027581693911112076}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:22:40,276] Trial 49 finished with value: 0.8330000042915344 and parameters: {'filters': 32, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.09698627357584336}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:22:46,241] Trial 50 finished with value: 0.9120000004768372 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.021383606934109418}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:22:51,963] Trial 51 finished with value: 0.9559999704360962 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.004329720354444118}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:22:57,954] Trial 52 finished with value: 0.9470000267028809 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.004365957371525451}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:23:05,846] Trial 53 finished with value: 0.9409999847412109 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.0086042084889256}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:23:14,397] Trial 54 finished with value: 0.9309999942779541 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.001445417249185236}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:23:24,258] Trial 55 finished with value: 0.9390000104904175 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.0025703563319565766}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:23:32,817] Trial 56 finished with value: 0.8820000290870667 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'linear', 'learning_rate': 0.0005309759223920821}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:23:42,223] Trial 57 finished with value: 0.9509999752044678 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.00776314921859591}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:23:54,026] Trial 58 finished with value: 0.550000011920929 and parameters: {'filters': 64, 'kernel_size': 3, 'strides': 2, 'activation': 'relu', 'learning_rate': 1.1100227821619273e-05}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:24:03,086] Trial 59 finished with value: 0.953000009059906 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.011135470292600265}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:24:20,668] Trial 60 finished with value: 0.949999988079071 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 1, 'activation': 'relu', 'learning_rate': 0.006346292748342753}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:24:29,198] Trial 61 finished with value: 0.9340000152587891 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.015108167551530051}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:24:38,751] Trial 62 finished with value: 0.9449999928474426 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.027795331294431704}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:24:56,487] Trial 63 finished with value: 0.9520000219345093 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 1, 'activation': 'relu', 'learning_rate': 0.0019432755205907233}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:25:05,362] Trial 64 finished with value: 0.9459999799728394 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 2, 'activation': 'relu', 'learning_rate': 0.011500235854685733}. Best is trial 14 with value: 0.9559999704360962.
# [I 2022-12-10 20:25:22,796] Trial 65 finished with value: 0.9539999961853027 and parameters: {'filters': 64, 'kernel_size': 5, 'strides': 1, 'activation': 'relu', 'learning_rate': 0.004008469992401856}. Best is trial 14 with value: 0.9559999704360962.
# Number of finished trials: 66
# Best trial:
#   Value: 0.9559999704360962
#   Params:
#     filters: 64
#     kernel_size: 5
#     strides: 2
#     activation: relu
#     learning_rate: 0.006701311861313489
